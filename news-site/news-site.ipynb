# %% [markdown]
# # Using NewsAPI

# %%
from newsapi import NewsApiClient

#Initialize API
newsapi = NewsApiClient(api_key='21e3e2faabef411d8cbdc6278313215c')

# %% [markdown]
# ## Get News

# %%
articles_query = newsapi.get_everything(
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2021-03-10',
                                      to='2021-03-11',
                                      language='en')

# %% [markdown]
# ## Convert news into pandas dataframe

# %%
all_articles = articles_query["articles"]
articles_df = pd.DataFrame([thing for thing in all_articles])
articles_df
# Out:
#                                         source  \
# 0     {'id': 'the-verge', 'name': 'The Verge'}
# 1     {'id': 'the-verge', 'name': 'The Verge'}
# 2       {'id': 'bbc-news', 'name': 'BBC News'}
# 3       {'id': 'bbc-news', 'name': 'BBC News'}
# 4       {'id': 'bbc-news', 'name': 'BBC News'}
# 5       {'id': 'bbc-news', 'name': 'BBC News'}
# 6     {'id': 'the-verge', 'name': 'The Verge'}
# 7   {'id': 'techcrunch', 'name': 'TechCrunch'}
# 8   {'id': 'techcrunch', 'name': 'TechCrunch'}
# 9       {'id': 'bbc-news', 'name': 'BBC News'}
# 10      {'id': 'bbc-news', 'name': 'BBC News'}
# 11      {'id': 'bbc-news', 'name': 'BBC News'}
# 12    {'id': 'the-verge', 'name': 'The Verge'}
# 13    {'id': 'the-verge', 'name': 'The Verge'}
# 14      {'id': 'bbc-news', 'name': 'BBC News'}
# 15      {'id': 'bbc-news', 'name': 'BBC News'}
# 16      {'id': 'bbc-news', 'name': 'BBC News'}
# 17      {'id': 'bbc-news', 'name': 'BBC News'}
# 18    {'id': 'the-verge', 'name': 'The Verge'}
# 19      {'id': 'bbc-news', 'name': 'BBC News'}
#
#                               author  \
# 0                       Zoe Schiffer
# 1                         Jay Peters
# 2   https://www.facebook.com/bbcnews
# 3   https://www.facebook.com/bbcnews
# 4   https://www.facebook.com/bbcnews
# 5                               None
# 6                        Monica Chin
# 7                         Anthony Ha
# 8                         Anthony Ha
# 9                               None
# 10                              None
# 11  https://www.facebook.com/bbcnews
# 12                   Allison Johnson
# 13                    Mitchell Clark
# 14                              None
# 15                              None
# 16  https://www.facebook.com/bbcnews
# 17                              None
# 18                        Nick Statt
# 19                              None
#
#                                                 title  \
# 0   Facebook’s ‘culture fit’ is the focus of a dis...
# 1   Microsoft says the latest Xbox Series X update...
# 2   De Blasio: NYC mayor calls on Cuomo to quit ov...
# 3   Covid in Scotland: Call to increase wedding gu...
# 4   The Scottish mercenary hired to kill Pablo Esc...
# 5   The drone's-eye view of a bowling alley that w...
# 6   The latest Windows 10 update could cause your ...
# 7   Daily Crunch: NFT artwork sells for $69M – Tec...
# 8            Daily Crunch: NFT artwork sells for $69M
# 9                                2021/03/11 23:00 GMT
# 10  Transfer rumours: Ronaldo, Messi, Haaland, Com...
